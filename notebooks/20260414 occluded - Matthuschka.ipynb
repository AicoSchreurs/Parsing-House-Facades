# %% [markdown]
# # Comparising images with and without overlapping objects within segmentation to evaluate ability for SAM2

# %% [markdown]
# In many Dutch residential areas, houses often have a small front gardens, resulting in façades that are frequently partially obscured by shrubs, trees, hedges, or other vegetation when viewed from the public street. This can affect the performance of computer vision models, particularly those tasked with façade segmentation or automated visual analysis of residential buildings. This can be the result of obscured architectural features, disrupted boundary detection, or irregular shapes that complicate segmentation tasks.
# So first images are divided in two categories depending on the extent to which vegetation obscure the façade elements that are labeled (i.e. windows, doors and solar panels), and the impact on segmentation accuracy of SAM is measured, by comparing segmentation outputs.

# %% [markdown]
# ## Imports

# %%
import os
import gc
import cv2
import csv

import json
import torch
import hydra
import shutil
import torchvision

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats
from PIL import Image, ImageDraw
from sam2.build_sam import build_sam2
from sam2.automatic_mask_generator import SAM2AutomaticMaskGenerator

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())

if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")

if device.type == "cuda":
    torch.autocast("cuda", dtype=torch.bfloat16).__enter__()

    if torch.cuda.get_device_properties(0).major >= 8:
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
# Out:
# PyTorch version: 2.7.1+cu118
# Torchvision version: 0.22.1+cu118
# CUDA is available: True
# Using device: cuda

# %% [markdown]
# ## Predefined variables

# %%
# The structure of directories to run the notebook
LABEL_DIR = "../images/Alles_JSONs"    # The ground truth labels
ALLES_DIR = "../images/Alles"          
ORIG_DIR = "../images/original"        
OBSCURED_DIR = "../images/occluded"    # This directory will be created and will contain the images where the groundtruth is occluded
VISIBLE_DIR = "../images/not_occluded" # This directory will be created and will contain the images where the groundtruth is not occluded
OUT_DIR = "../outputs"                 # output images will ne written there
RESULTS_DIR = "../results"             # resulting metrics will be written there
RESIZE_DIR = "../images/resized"
COLOR_DIR = "../images/grayscale"

LABEL_COLORS = {
    "Raam": [0.2, 0.6, 1.0],
    "Deur": [0.8, 0.2, 0.2],
    "Zonnepaneel": [1.0, 0.85, 0.0]
}

# Define the different attributes that are varied in the research
IMAGE_CONDITIONS = {
   "original": ORIG_DIR,
    "resized": RESIZE_DIR,
    "grayscale": COLOR_DIR,
    "occluded": OBSCURED_DIR,
    "not_occluded": VISIBLE_DIR
}

RESIZE_FORMAT = (512, 512)
COLOR = (0, 0, 0)

os.makedirs(ORIG_DIR, exist_ok=True)
os.makedirs(OBSCURED_DIR, exist_ok=True)
os.makedirs(VISIBLE_DIR, exist_ok=True)
os.makedirs(OUT_DIR, exist_ok=True)
os.makedirs(LABEL_DIR, exist_ok=True)

# Model
SAM2_CHECKPOINT_PATH = "../sam2/checkpoints/sam2.1_hiera_small.pt"
SAM2_MODEL_CONFIG_PATH = "configs/sam2.1/sam2.1_hiera_s.yaml"

device = 'cuda:0'

# %%
hydra.core.global_hydra.GlobalHydra.instance().clear()
hydra.initialize_config_module(config_module="sam2", version_base="1.2")
# Out:
# hydra.initialize_config_module()

# %% [markdown]
# ## Copy the original images to the correct directories
#
# The directory __"occluded"__ contains images of house façades that are occluded in such a way that:
# - not all the corners of the labeled window(s), door or solar panel can not be "seen" or
# - the labeled object to segment is more than 50% covered.
#
# The directory __"not_occluded"__ contains images of house façades that are NOT occluded in such a way that:
# - all the corners of the labeled window(s), door or solar panel can not be "seen" AND
# - the labeled object to segment are less than 50% covered.

# %%
import os
import shutil

# List of files that have to be copied to the directory 'not_occluded':

not_occluded_files = [
"image_4.jpg", "image_7.jpg", "image_8.jpg", "image_13.jpg",
"image_15.jpg", "image_18.jpg", "image_19.jpg", "image_23.jpg",
"image_24.jpg", "image_25.jpg", "image_31.jpg", "image_33.jpg",
"image_37.jpg", "image_38.jpg", "image_41.jpg", "image_42.jpg",
"image_43.jpg", "image_46.jpg", "image_48.jpg", "image_49.jpg",
"image_52.jpg", "image_54.jpg", "image_59.jpg", "image_69.jpg",
"image_72.jpg", "image_73.jpg", "image_79.jpg", "image_86.jpg",
"image_87.jpg", "image_91.jpg", "image_93.jpg", "image_95.jpg",
"image_97.jpg", "image_103.jpg", "image_109.jpg", "image_110.jpg",
"image_111.jpg", "image_112.jpg", "image_113.jpg", "image_114.jpg",
"image_126.jpg", "image_146.jpg", "image_148.jpg", "image_151.jpg",
"image_156.jpg", "image_160.jpg", "image_162.jpg", "image_171.jpg",
"image_176.jpg", "image_177.jpg", "image_185.jpg", "image_193.jpg",
"image_207.jpg", "image_208.jpg", "image_209.jpg", "image_210.jpg",
"image_223.jpg", "image_224.jpg", "image_227.jpg", "image_239.jpg",
"image_243.jpg", "image_251.jpg", "image_254.jpg", "image_266.jpg",
"image_267.jpg", "image_268.jpg", "image_275.jpg", "image_278.jpg",
"image_279.jpg", "image_280.jpg", "image_281.jpg", "image_282.jpg",
"image_283.jpg", "image_284.jpg", "image_285.jpg", "image_286.jpg",
"image_287.jpg", "image_289.jpg", "image_292.jpg", "image_293.jpg",
"image_294.jpg", "image_295.jpg", "image_297.jpg", "image_299.jpg",
"image_306.jpg", "image_311.jpg", "image_318.jpg", "image_319.jpg",
"image_322.jpg", "image_327.jpg", "image_329.jpg", "image_332.jpg",
"image_334.jpg", "image_335.jpg", "image_337.jpg", "image_346.jpg",
"image_349.jpg", "image_352.jpg", "image_356.jpg", "image_372.jpg",
"image_374.jpg", "image_376.jpg", "image_385.jpg", "image_393.jpg",
"image_395.jpg", "image_401.jpg", "image_402.jpg", "image_404.jpg",
"image_405.jpg", "image_408.jpg", "image_415.jpg", "image_416.jpg",
"image_417.jpg", "image_424.jpg", "image_427.jpg", "image_428.jpg",
"image_432.jpg", "image_437.jpg", "image_443.jpg", "image_446.jpg",
"image_447.jpg", "image_455.jpg", "image_465.jpg", "image_467.jpg",
"image_469.jpg", "image_470.jpg", "image_473.jpg", "image_477.jpg",
"image_478.jpg", "image_481.jpg", "image_484.jpg", "image_486.jpg",
"image_487.jpg", "image_488.jpg", "image_489.jpg", "image_495.jpg",
"image_496.jpg"
]

# List of files that have to be copied to the directory 'not_occluded', since not all original scraped images are selected to be suitable (like living rooms):

occluded_files = [
"image_9.jpg", "image_10.jpg", "image_14.jpg", "image_17.jpg",
"image_26.jpg", "image_27.jpg", "image_28.jpg", "image_30.jpg",
"image_32.jpg", "image_35.jpg", "image_36.jpg", "image_40.jpg",
"image_44.jpg", "image_45.jpg", "image_47.jpg", "image_51.jpg",
"image_56.jpg", "image_57.jpg", "image_60.jpg", "image_61.jpg",
"image_62.jpg", "image_66.jpg", "image_71.jpg", "image_77.jpg",
"image_78.jpg", "image_80.jpg", "image_81.jpg", "image_82.jpg",
"image_85.jpg", "image_88.jpg", "image_90.jpg", "image_92.jpg",
"image_96.jpg", "image_99.jpg", "image_104.jpg", "image_105.jpg",
"image_107.jpg", "image_123.jpg", "image_124.jpg", "image_129.jpg",
"image_130.jpg", "image_131.jpg", "image_132.jpg", "image_133.jpg",
"image_135.jpg", "image_136.jpg", "image_137.jpg", "image_138.jpg",
"image_139.jpg", "image_141.jpg", "image_147.jpg", "image_157.jpg",
"image_158.jpg", "image_159.jpg", "image_161.jpg", "image_164.jpg",
"image_165.jpg", "image_169.jpg", "image_172.jpg", "image_174.jpg",
"image_175.jpg", "image_179.jpg", "image_180.jpg", "image_182.jpg",
"image_183.jpg", "image_184.jpg", "image_187.jpg", "image_191.jpg",
"image_195.jpg", "image_197.jpg", "image_198.jpg", "image_200.jpg",
"image_201.jpg", "image_202.jpg", "image_204.jpg", "image_206.jpg",
"image_213.jpg", "image_214.jpg", "image_216.jpg", "image_217.jpg",
"image_218.jpg", "image_221.jpg", "image_222.jpg", "image_226.jpg",
"image_228.jpg", "image_231.jpg", "image_232.jpg", "image_234.jpg",
"image_235.jpg", "image_236.jpg", "image_237.jpg", "image_238.jpg",
"image_240.jpg", "image_241.jpg", "image_245.jpg", "image_246.jpg",
"image_249.jpg", "image_255.jpg", "image_257.jpg", "image_258.jpg",
"image_261.jpg", "image_262.jpg", "image_263.jpg", "image_264.jpg",
"image_265.jpg", "image_270.jpg", "image_271.jpg", "image_272.jpg",
"image_273.jpg", "image_274.jpg", "image_276.jpg", "image_277.jpg",
"image_300.jpg", "image_301.jpg", "image_302.jpg", "image_303.jpg",
"image_304.jpg", "image_307.jpg", "image_309.jpg", "image_310.jpg",
"image_312.jpg", "image_313.jpg", "image_317.jpg", "image_321.jpg",
"image_323.jpg", "image_324.jpg", "image_326.jpg", "image_328.jpg",
"image_330.jpg", "image_331.jpg", "image_336.jpg", "image_338.jpg",
"image_339.jpg", "image_340.jpg", "image_347.jpg", "image_350.jpg",
"image_353.jpg", "image_354.jpg", "image_358.jpg", "image_359.jpg",
"image_360.jpg", "image_365.jpg", "image_366.jpg", "image_367.jpg",
"image_368.jpg", "image_369.jpg", "image_370.jpg", "image_373.jpg",
"image_377.jpg", "image_380.jpg", "image_381.jpg", "image_382.jpg",
"image_383.jpg", "image_387.jpg", "image_388.jpg", "image_389.jpg",
"image_391.jpg", "image_394.jpg", "image_398.jpg", "image_403.jpg",
"image_406.jpg", "image_407.jpg", "image_410.jpg", "image_411.jpg",
"image_414.jpg", "image_418.jpg", "image_420.jpg", "image_421.jpg",
"image_423.jpg", "image_425.jpg", "image_426.jpg", "image_429.jpg",
"image_430.jpg", "image_431.jpg", "image_433.jpg", "image_434.jpg",
"image_435.jpg", "image_436.jpg", "image_440.jpg", "image_442.jpg",
"image_445.jpg", "image_448.jpg", "image_449.jpg", "image_450.jpg",
"image_452.jpg", "image_453.jpg", "image_456.jpg", "image_457.jpg",
"image_458.jpg", "image_459.jpg", "image_461.jpg", "image_462.jpg",
"image_463.jpg", "image_466.jpg", "image_471.jpg", "image_479.jpg",
"image_480.jpg", "image_482.jpg", "image_483.jpg", "image_485.jpg",
"image_490.jpg", "image_492.jpg", "image_493.jpg", "image_494.jpg",
"image_497.jpg"  
]

# Source and destiny directories
source_dir = ORIG_DIR
occluded_dir = OBSCURED_DIR
not_occluded_dir = VISIBLE_DIR

# Create directories if necessary
os.makedirs(occluded_dir, exist_ok=True)
os.makedirs(not_occluded_dir, exist_ok=True)

# Copy files to correct directory
for filename in os.listdir(source_dir):
    if filename in not_occluded_files:
        shutil.copy(os.path.join(source_dir, filename), not_occluded_dir)
    else:
        if filename in occluded_files:
            shutil.copy(os.path.join(source_dir, filename), occluded_dir)

print("Files are all copied to the correct directory.")
# Out:
# Files are all copied to the correct directory.

# %% [markdown]
# ## SAM 2

# %% [markdown]
# ### Build model

# %%
sam2 = build_sam2(SAM2_MODEL_CONFIG_PATH, SAM2_CHECKPOINT_PATH, device=device, apply_postprocessing=False)

mask_generator = SAM2AutomaticMaskGenerator(
    model=sam2,
    points_per_side=16,
    points_per_batch=128,
    pred_iou_thresh=0.75,
    stability_score_thresh=0.9,
    stability_score_offset=0.7,
    # crop_n_layers=0,
    box_nms_thresh=0.5,
    # crop_n_points_downscale_factor=2,
    min_mask_region_area=250,
    # use_m2m=True
)

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Get attributes from .JSON file like shapes, height and width

# %%
#################################################
#      Gets attributes from the annotation      #
#################################################

def get_attr_annotation(json_path):
    with open(json_path, "r") as f:
        annotation = json.load(f)

    height = data.get("imageHeight")
    width = data.get("imageWidth")
    
    shapes = []
    for shape in annotation["shapes"]:
        shapes.append(shape)

    return {**annotation, "shapes": shapes, "imageWidth": width, "imageHeight": height, "imageData": None}

# %% [markdown]
# ## Transform the different forms to masks

# %%
def polygon_to_mask(points, img_h, img_w):
    if len(points) < 3:
        print(f"  WARNING: Polygon only has {len(points)} point(s), skipped.")
        return np.zeros((img_h, img_w), dtype=bool)
    
    mask = Image.new("L", (img_w, img_h), 0)
    ImageDraw.Draw(mask).polygon([(x, y) for x, y in points], outline=1, fill=1)
    return np.array(mask, dtype=bool)

# %%
def circle_to_mask(points, img_h, img_w):
    if len(points) < 2:
        print(f"  WARNING: Circle only has {len(points)} point(s), skipped.")
        return np.zeros((img_h, img_w), dtype=bool)
    
    cx, cy = points[0]
    rx, ry = points[1]
    radius = np.sqrt((rx-cx)**2 + (ry-cy)**2)

    mask = Image.new("L", (img_w, img_h), 0)
    ImageDraw.Draw(mask).ellipse([cx - radius, cy - radius, cx + radius, cy + radius], outline=1, fill=1)
    return np.array(mask, dtype=bool)

# %%
def rectangle_to_mask(points, img_h, img_w):
    if len(points) < 2:
        print(f"  WARNING: Rectangle only has {len(points)} point(s), skipped.")
        return np.zeros((img_h, img_w), dtype=bool)
    
    x1, y1 = points[0]
    x2, y2 = points[1]

    x_min, x_max = min(x1, x2), max(x1, x2)
    y_min, y_max = min(y1, y2), max(y1, y2)

    mask = Image.new("L", (img_w, img_h), 0)
    ImageDraw.Draw(mask).rectangle([x_min, y_min, x_max, y_max], outline=1, fill=1)
    return np.array(mask, dtype=bool)

# %%
def load_gt_masks(json_path, img_h, img_w):
    with open(json_path, "r") as f:
        data = json.load(f)

    masks = []
    for s in data["shapes"]:
        shape_type = s["shape_type"]
        points = s["points"]

        if shape_type == "polygon":
            mask = polygon_to_mask(points, img_h, img_w)
        elif shape_type == "circle":
            mask = circle_to_mask(points, img_h, img_w)
        elif shape_type == "rectangle":
            mask = rectangle_to_mask(points, img_h, img_w)
        else:
            print(f"  WARNING: Unsupported shape type '{shape_type}' in {json_path}, skipping.")
            continue

        if mask.sum() == 0:
            print(f"  WARNING: Generated empty mask for shape type '{shape_type}' in {json_path}, skipping.")
            continue

        masks.append({"label": s["label"], "mask": mask})

    return masks

# %%
# Calculates the overlap of the predicted segmentation and the ground truth, result will be between 0 and 1.
# No overlap being 0, total overlap being 1

def compute_iou(mask1, mask2):
    intersection = np.logical_and(mask1, mask2).sum()
    union = np.logical_or(mask1, mask2).sum()
    return intersection / union if union > 0 else 0.0

# %%
def mask_overlaps_annotation(sam_mask, gt_masks, threshold=0.3):
    best_iou = 0.0
    best_label = None

    for gt in gt_masks:
        iou = compute_iou(sam_mask, gt["mask"])
        if iou > best_iou:
            best_iou = iou
            best_label = gt["label"]
    
    if best_iou >= threshold:
        return True, best_label, best_iou
    
    return False, None, 0.0

# %%
def filter_masks_by_annotation(sam_masks, gt_masks, iou_threshold=0.3):
    filtered_masks = []
    
    for sam in sam_masks:
        keep, label, iou = mask_overlaps_annotation(sam["segmentation"], gt_masks, threshold=iou_threshold)
        if keep:
            filtered_masks.append({**sam, "label": label, "annot_iou": iou})

    return filtered_masks

# %%
def reproject_mask_to_original(mask, orig_w, orig_h, target_w=RESIZE_FORMAT[0], target_h=RESIZE_FORMAT[1]):
    scale, pad_left, pad_top = get_resize_transform_params(orig_w, orig_h, target_w, target_h)

    new_w = int(orig_w * scale)
    new_h = int(orig_h * scale)
    mask_cropped = mask[pad_top:pad_top+new_h, pad_left:pad_left+new_w]

    reprojected = cv2.resize(mask_cropped.astype(np.uint8), (orig_w, orig_h), interpolation=cv2.INTER_NEAREST)
    return reprojected.astype(bool)

# %%
def match_and_score(ref_masks, cmp_masks):
    results = []
    for ref in ref_masks:
        best_iou = 0.0

        for cmp in cmp_masks:
            if cmp["label"] != ref["label"]:
                continue
            iou = compute_iou(ref["segmentation"], cmp["segmentation"])
            if iou > best_iou:
                best_iou = iou
        results.append({"label": ref["label"], "annot_iou": best_iou})
        
    return results

# %%
def save_masked_visualization(image_rgb, filtered_masks, gt_masks, filename, condition, output_dir=OUT_DIR):
    fig, axes = plt.subplots(1, 2, figsize=(20, 10))

    axes[0].imshow(image_rgb.astype(np.float32) / 255.0)
    gt_overlay = np.zeros((*image_rgb.shape[:2], 4), dtype=np.float32)
    for gt in gt_masks:
        color = LABEL_COLORS.get(gt["label"], [0.5, 0.5, 0.5])
        gt_overlay[gt["mask"]] = list(color) + [0.4]
    axes[0].imshow(gt_overlay)
    axes[0].set_title(f"{condition.capitalize()} - Ground Truth", fontsize=12)
    axes[0].axis("off")

    axes[1].imshow(image_rgb.astype(np.float32) / 255.0)
    sam_overlay = np.zeros((*image_rgb.shape[:2], 4), dtype=np.float32)
    for m in filtered_masks:
        color = LABEL_COLORS.get(m["label"], [0.5, 0.5, 0.5])
        sam_overlay[m["segmentation"]] = list(color) + [0.5]

        contours, _ = cv2.findContours(m["segmentation"].astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        cv2.drawContours(sam_overlay, contours, -1, list(color) + [1.0], thickness=1)

        ys, xs = np.where(m["segmentation"])
        if len(xs) > 0 and len(ys) > 0:
            center_x = int(xs.mean())
            center_y = int(ys.mean())
            axes[1].text(center_x, center_y, m["label"], color="white", fontsize=8, ha="center", va="center", bbox=dict(boxstyle="round,pad=0.1",facecolor='black', alpha=0.5, edgecolor='none'))

    axes[1].imshow(sam_overlay)
    axes[1].set_title(f"{condition.capitalize()} - {len(filtered_masks)} SAM Masks", fontsize=12)
    axes[1].axis("off")

    legend_handles = [
        plt.Rectangle((0, 0), 1, 1, color=LABEL_COLORS.get(label, [0.5, 0.5, 0.5])) for label in LABEL_COLORS
    ]
    axes[1].legend(legend_handles, LABEL_COLORS.keys(), loc="lower right", fontsize=8)

    save_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_{condition}.png")
    plt.savefig(save_path, bbox_inches="tight", dpi=150)
    plt.close()
    print(f"  Visualization saved to {save_path}")

# %%
def get_resize_transform_params(orig_w, orig_h, target_w=RESIZE_FORMAT[0], target_h=RESIZE_FORMAT[1]):
    scale = min(target_w / orig_w, target_h / orig_h)

    new_w = int(orig_w * scale)
    new_h = int(orig_h * scale)

    pad_left = (target_w - new_w) // 2
    pad_top = (target_h - new_h) // 2

    return scale, pad_left, pad_top

# %%
def transform_annotation(json_path, orig_w, orig_h, target_w=RESIZE_FORMAT[0], target_h=RESIZE_FORMAT[1]):
    with open(json_path, "r") as f:
        annotation = json.load(f)

    scale, pad_left, pad_top = get_resize_transform_params(orig_w, orig_h, target_w, target_h)

    new_shapes = []
    for shape in annotation["shapes"]:
        new_points = [[x*scale + pad_left, y*scale + pad_top] for x, y in shape["points"]]
        new_shape = shape.copy()
        new_shape["points"] = new_points
        new_shapes.append(new_shape)

    return {**annotation, "shapes": new_shapes, "imageWidth": target_w, "imageHeight": target_h, "imageData": None}

# %%
all_results = {}

for condition, img_dir in IMAGE_CONDITIONS.items():
    all_results[condition] = {}

# %% [markdown]
# ## Run the model on the partly occluded images

# %%
##############################################################
#                                                            #
#   Filter all the images in the occluded dir and run model  #
#                                                            #
##############################################################
OCC_IMAGES = [f for f in os.listdir(OBSCURED_DIR) if f.endswith((".jpg", ".jpeg", ".png"))]

for file in sorted(OCC_IMAGES):
    json_file = os.path.join(LABEL_DIR, os.path.splitext(file)[0] + ".json")
    if not os.path.exists(json_file):

        # Not all scraped images were considered suitable for defining ground truth. 
        # Warn that this file has no .json and is not included in futher processing
        print(f"\t  WARNING: No annotation found for {file} in occluded directory, skipping.")
        continue

    print(f"Processing {file}...")

    img_occ = Image.open(os.path.join(OBSCURED_DIR, file)).convert("RGB")
    occ_array = np.array(img_occ)
    img_h, img_w = occ_array.shape[:2]

    # Get the ground truth annotation
    gt_occ = load_gt_masks(json_file, img_h, img_w)
    
    # Use model on array
    sam_occ = mask_generator.generate(occ_array)
    filtered_occ = filter_masks_by_annotation(sam_occ, gt_occ)
    all_results["occluded"][file] = [
        {"label": m["label"], "annot_iou": m["annot_iou"]} for m in filtered_occ
    ]
    save_masked_visualization(occ_array, filtered_occ, gt_occ, file, "occluded", OUT_DIR)
    print(f"\t  Occluded: {len(filtered_occ)} SAM masks inside annotations.")

    # Free memory
    del sam_occ
    del filtered_occ
    del occ_array
    gc.collect()

    if torch.cuda.is_available():
        torch.cuda.empty_cache()
# Out:
# Processing image_10.jpg...
#   Visualization saved to ../outputs\image_10_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_104.jpg...
#   Visualization saved to ../outputs\image_104_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_105.jpg...
#   Visualization saved to ../outputs\image_105_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_107.jpg...
#   Visualization saved to ../outputs\image_107_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_123.jpg...
#   Visualization saved to ../outputs\image_123_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_124.jpg...
#   Visualization saved to ../outputs\image_124_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_129.jpg...
#   Visualization saved to ../outputs\image_129_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_130.jpg...
#   Visualization saved to ../outputs\image_130_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_131.jpg...
#   Visualization saved to ../outputs\image_131_occluded.png
# 	  Occluded: 11 SAM masks inside annotations.
# Processing image_132.jpg...
#   Visualization saved to ../outputs\image_132_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_133.jpg...
#   Visualization saved to ../outputs\image_133_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_135.jpg...
#   Visualization saved to ../outputs\image_135_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_136.jpg...
#   Visualization saved to ../outputs\image_136_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_137.jpg...
#   Visualization saved to ../outputs\image_137_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_138.jpg...
#   Visualization saved to ../outputs\image_138_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_139.jpg...
#   Visualization saved to ../outputs\image_139_occluded.png
# 	  Occluded: 12 SAM masks inside annotations.
# Processing image_14.jpg...
#   Visualization saved to ../outputs\image_14_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_141.jpg...
#   Visualization saved to ../outputs\image_141_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_147.jpg...
#   Visualization saved to ../outputs\image_147_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_157.jpg...
#   Visualization saved to ../outputs\image_157_occluded.png
# 	  Occluded: 14 SAM masks inside annotations.
# Processing image_158.jpg...
#   Visualization saved to ../outputs\image_158_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_159.jpg...
#   Visualization saved to ../outputs\image_159_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_161.jpg...
#   Visualization saved to ../outputs\image_161_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_164.jpg...
#   Visualization saved to ../outputs\image_164_occluded.png
# 	  Occluded: 0 SAM masks inside annotations.
# Processing image_165.jpg...
#   Visualization saved to ../outputs\image_165_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_169.jpg...
#   Visualization saved to ../outputs\image_169_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_17.jpg...
#   Visualization saved to ../outputs\image_17_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_172.jpg...
#   Visualization saved to ../outputs\image_172_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_174.jpg...
#   Visualization saved to ../outputs\image_174_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_175.jpg...
#   Visualization saved to ../outputs\image_175_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_179.jpg...
#   Visualization saved to ../outputs\image_179_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_180.jpg...
#   Visualization saved to ../outputs\image_180_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_182.jpg...
#   Visualization saved to ../outputs\image_182_occluded.png
# 	  Occluded: 12 SAM masks inside annotations.
# Processing image_183.jpg...
#   Visualization saved to ../outputs\image_183_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_184.jpg...
#   Visualization saved to ../outputs\image_184_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_187.jpg...
#   Visualization saved to ../outputs\image_187_occluded.png
# 	  Occluded: 11 SAM masks inside annotations.
# Processing image_191.jpg...
#   Visualization saved to ../outputs\image_191_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_195.jpg...
#   Visualization saved to ../outputs\image_195_occluded.png
# 	  Occluded: 13 SAM masks inside annotations.
# Processing image_197.jpg...
#   Visualization saved to ../outputs\image_197_occluded.png
# 	  Occluded: 10 SAM masks inside annotations.
# Processing image_198.jpg...
#   Visualization saved to ../outputs\image_198_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_200.jpg...
#   Visualization saved to ../outputs\image_200_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_201.jpg...
#   Visualization saved to ../outputs\image_201_occluded.png
# 	  Occluded: 17 SAM masks inside annotations.
# Processing image_202.jpg...
#   Visualization saved to ../outputs\image_202_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_204.jpg...
#   Visualization saved to ../outputs\image_204_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_206.jpg...
#   Visualization saved to ../outputs\image_206_occluded.png
# 	  Occluded: 14 SAM masks inside annotations.
# Processing image_213.jpg...
#   Visualization saved to ../outputs\image_213_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_214.jpg...
#   Visualization saved to ../outputs\image_214_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_216.jpg...
#   Visualization saved to ../outputs\image_216_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_217.jpg...
#   Visualization saved to ../outputs\image_217_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_218.jpg...
#   Visualization saved to ../outputs\image_218_occluded.png
# 	  Occluded: 15 SAM masks inside annotations.
# Processing image_221.jpg...
#   Visualization saved to ../outputs\image_221_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_222.jpg...
#   Visualization saved to ../outputs\image_222_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_226.jpg...
#   Visualization saved to ../outputs\image_226_occluded.png
# 	  Occluded: 16 SAM masks inside annotations.
# Processing image_228.jpg...
#   Visualization saved to ../outputs\image_228_occluded.png
# 	  Occluded: 1 SAM masks inside annotations.
# Processing image_231.jpg...
#   Visualization saved to ../outputs\image_231_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_232.jpg...
#   Visualization saved to ../outputs\image_232_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_234.jpg...
#   Visualization saved to ../outputs\image_234_occluded.png
# 	  Occluded: 13 SAM masks inside annotations.
# Processing image_235.jpg...
#   Visualization saved to ../outputs\image_235_occluded.png
# 	  Occluded: 11 SAM masks inside annotations.
# Processing image_236.jpg...
#   Visualization saved to ../outputs\image_236_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_237.jpg...
#   Visualization saved to ../outputs\image_237_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_238.jpg...
#   Visualization saved to ../outputs\image_238_occluded.png
# 	  Occluded: 1 SAM masks inside annotations.
# Processing image_240.jpg...
#   Visualization saved to ../outputs\image_240_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_241.jpg...
#   Visualization saved to ../outputs\image_241_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_245.jpg...
#   Visualization saved to ../outputs\image_245_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_246.jpg...
#   Visualization saved to ../outputs\image_246_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_249.jpg...
#   Visualization saved to ../outputs\image_249_occluded.png
# 	  Occluded: 16 SAM masks inside annotations.
# Processing image_255.jpg...
#   Visualization saved to ../outputs\image_255_occluded.png
# 	  Occluded: 14 SAM masks inside annotations.
# Processing image_257.jpg...
#   Visualization saved to ../outputs\image_257_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_258.jpg...
#   Visualization saved to ../outputs\image_258_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_26.jpg...
#   Visualization saved to ../outputs\image_26_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_261.jpg...
#   Visualization saved to ../outputs\image_261_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_262.jpg...
#   Visualization saved to ../outputs\image_262_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_263.jpg...
#   Visualization saved to ../outputs\image_263_occluded.png
# 	  Occluded: 18 SAM masks inside annotations.
# Processing image_264.jpg...
#   Visualization saved to ../outputs\image_264_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_265.jpg...
#   Visualization saved to ../outputs\image_265_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_27.jpg...
#   Visualization saved to ../outputs\image_27_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_270.jpg...
#   Visualization saved to ../outputs\image_270_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_271.jpg...
#   Visualization saved to ../outputs\image_271_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_272.jpg...
#   WARNING: Polygon only has 2 point(s), skipped.
#   WARNING: Generated empty mask for shape type 'polygon' in ../images/Alles_JSONs\image_272.json, skipping.
#   Visualization saved to ../outputs\image_272_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_273.jpg...
#   Visualization saved to ../outputs\image_273_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_274.jpg...
#   Visualization saved to ../outputs\image_274_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_276.jpg...
#   Visualization saved to ../outputs\image_276_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_277.jpg...
#   Visualization saved to ../outputs\image_277_occluded.png
# 	  Occluded: 0 SAM masks inside annotations.
# Processing image_28.jpg...
#   Visualization saved to ../outputs\image_28_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_30.jpg...
#   Visualization saved to ../outputs\image_30_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_300.jpg...
#   Visualization saved to ../outputs\image_300_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_301.jpg...
#   Visualization saved to ../outputs\image_301_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_302.jpg...
#   Visualization saved to ../outputs\image_302_occluded.png
# 	  Occluded: 11 SAM masks inside annotations.
# Processing image_303.jpg...
#   Visualization saved to ../outputs\image_303_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_304.jpg...
#   Visualization saved to ../outputs\image_304_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_307.jpg...
#   Visualization saved to ../outputs\image_307_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_309.jpg...
#   Visualization saved to ../outputs\image_309_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_310.jpg...
#   Visualization saved to ../outputs\image_310_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_312.jpg...
#   Visualization saved to ../outputs\image_312_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_313.jpg...
#   Visualization saved to ../outputs\image_313_occluded.png
# 	  Occluded: 1 SAM masks inside annotations.
# Processing image_317.jpg...
#   Visualization saved to ../outputs\image_317_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_32.jpg...
#   Visualization saved to ../outputs\image_32_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_321.jpg...
#   Visualization saved to ../outputs\image_321_occluded.png
# 	  Occluded: 10 SAM masks inside annotations.
# Processing image_323.jpg...
#   Visualization saved to ../outputs\image_323_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_324.jpg...
#   Visualization saved to ../outputs\image_324_occluded.png
# 	  Occluded: 0 SAM masks inside annotations.
# Processing image_326.jpg...
#   Visualization saved to ../outputs\image_326_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_328.jpg...
#   Visualization saved to ../outputs\image_328_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_330.jpg...
#   Visualization saved to ../outputs\image_330_occluded.png
# 	  Occluded: 1 SAM masks inside annotations.
# Processing image_331.jpg...
#   Visualization saved to ../outputs\image_331_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_336.jpg...
#   Visualization saved to ../outputs\image_336_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_338.jpg...
#   Visualization saved to ../outputs\image_338_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_339.jpg...
#   Visualization saved to ../outputs\image_339_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_340.jpg...
#   Visualization saved to ../outputs\image_340_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_347.jpg...
#   Visualization saved to ../outputs\image_347_occluded.png
# 	  Occluded: 0 SAM masks inside annotations.
# Processing image_35.jpg...
#   Visualization saved to ../outputs\image_35_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_350.jpg...
#   Visualization saved to ../outputs\image_350_occluded.png
# 	  Occluded: 10 SAM masks inside annotations.
# Processing image_353.jpg...
#   Visualization saved to ../outputs\image_353_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_354.jpg...
#   Visualization saved to ../outputs\image_354_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_358.jpg...
#   Visualization saved to ../outputs\image_358_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_359.jpg...
#   Visualization saved to ../outputs\image_359_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_36.jpg...
#   Visualization saved to ../outputs\image_36_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_360.jpg...
#   Visualization saved to ../outputs\image_360_occluded.png
# 	  Occluded: 11 SAM masks inside annotations.
# Processing image_365.jpg...
#   Visualization saved to ../outputs\image_365_occluded.png
# 	  Occluded: 13 SAM masks inside annotations.
# Processing image_366.jpg...
#   Visualization saved to ../outputs\image_366_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_367.jpg...
#   Visualization saved to ../outputs\image_367_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_368.jpg...
#   Visualization saved to ../outputs\image_368_occluded.png
# 	  Occluded: 12 SAM masks inside annotations.
# Processing image_369.jpg...
#   Visualization saved to ../outputs\image_369_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_370.jpg...
#   Visualization saved to ../outputs\image_370_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_373.jpg...
#   Visualization saved to ../outputs\image_373_occluded.png
# 	  Occluded: 11 SAM masks inside annotations.
# Processing image_377.jpg...
#   Visualization saved to ../outputs\image_377_occluded.png
# 	  Occluded: 14 SAM masks inside annotations.
# Processing image_380.jpg...
#   Visualization saved to ../outputs\image_380_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_381.jpg...
#   Visualization saved to ../outputs\image_381_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_382.jpg...
#   Visualization saved to ../outputs\image_382_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_383.jpg...
#   Visualization saved to ../outputs\image_383_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_387.jpg...
#   Visualization saved to ../outputs\image_387_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_388.jpg...
#   Visualization saved to ../outputs\image_388_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_389.jpg...
#   Visualization saved to ../outputs\image_389_occluded.png
# 	  Occluded: 13 SAM masks inside annotations.
# Processing image_391.jpg...
#   Visualization saved to ../outputs\image_391_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_394.jpg...
#   Visualization saved to ../outputs\image_394_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_398.jpg...
#   Visualization saved to ../outputs\image_398_occluded.png
# 	  Occluded: 12 SAM masks inside annotations.
# Processing image_40.jpg...
#   Visualization saved to ../outputs\image_40_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_403.jpg...
#   Visualization saved to ../outputs\image_403_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_406.jpg...
#   Visualization saved to ../outputs\image_406_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_407.jpg...
#   Visualization saved to ../outputs\image_407_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_410.jpg...
#   Visualization saved to ../outputs\image_410_occluded.png
# 	  Occluded: 15 SAM masks inside annotations.
# Processing image_411.jpg...
#   Visualization saved to ../outputs\image_411_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_414.jpg...
#   Visualization saved to ../outputs\image_414_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_418.jpg...
#   Visualization saved to ../outputs\image_418_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_420.jpg...
#   Visualization saved to ../outputs\image_420_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_421.jpg...
#   Visualization saved to ../outputs\image_421_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_423.jpg...
#   Visualization saved to ../outputs\image_423_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_425.jpg...
#   Visualization saved to ../outputs\image_425_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_426.jpg...
#   Visualization saved to ../outputs\image_426_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_429.jpg...
#   Visualization saved to ../outputs\image_429_occluded.png
# 	  Occluded: 11 SAM masks inside annotations.
# Processing image_430.jpg...
#   Visualization saved to ../outputs\image_430_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_431.jpg...
#   Visualization saved to ../outputs\image_431_occluded.png
# 	  Occluded: 13 SAM masks inside annotations.
# Processing image_433.jpg...
#   Visualization saved to ../outputs\image_433_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_434.jpg...
#   Visualization saved to ../outputs\image_434_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_435.jpg...
#   Visualization saved to ../outputs\image_435_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_436.jpg...
#   Visualization saved to ../outputs\image_436_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_44.jpg...
#   WARNING: Rectangle only has 1 point(s), skipped.
#   WARNING: Generated empty mask for shape type 'rectangle' in ../images/Alles_JSONs\image_44.json, skipping.
#   Visualization saved to ../outputs\image_44_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_440.jpg...
#   Visualization saved to ../outputs\image_440_occluded.png
# 	  Occluded: 10 SAM masks inside annotations.
# Processing image_442.jpg...
#   Visualization saved to ../outputs\image_442_occluded.png
# 	  Occluded: 12 SAM masks inside annotations.
# Processing image_445.jpg...
#   Visualization saved to ../outputs\image_445_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_448.jpg...
#   Visualization saved to ../outputs\image_448_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_449.jpg...
#   Visualization saved to ../outputs\image_449_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_45.jpg...
#   Visualization saved to ../outputs\image_45_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_450.jpg...
#   Visualization saved to ../outputs\image_450_occluded.png
# 	  Occluded: 1 SAM masks inside annotations.
# Processing image_452.jpg...
#   Visualization saved to ../outputs\image_452_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_453.jpg...
#   Visualization saved to ../outputs\image_453_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_456.jpg...
#   Visualization saved to ../outputs\image_456_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_457.jpg...
#   Visualization saved to ../outputs\image_457_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_458.jpg...
#   Visualization saved to ../outputs\image_458_occluded.png
# 	  Occluded: 2 SAM masks inside annotations.
# Processing image_459.jpg...
#   Visualization saved to ../outputs\image_459_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_461.jpg...
#   Visualization saved to ../outputs\image_461_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_462.jpg...
#   Visualization saved to ../outputs\image_462_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_463.jpg...
#   Visualization saved to ../outputs\image_463_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_466.jpg...
#   Visualization saved to ../outputs\image_466_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_47.jpg...
#   Visualization saved to ../outputs\image_47_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_471.jpg...
#   Visualization saved to ../outputs\image_471_occluded.png
# 	  Occluded: 1 SAM masks inside annotations.
# Processing image_479.jpg...
#   Visualization saved to ../outputs\image_479_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_480.jpg...
#   Visualization saved to ../outputs\image_480_occluded.png
# 	  Occluded: 10 SAM masks inside annotations.
# Processing image_482.jpg...
#   Visualization saved to ../outputs\image_482_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_483.jpg...
#   Visualization saved to ../outputs\image_483_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_485.jpg...
#   Visualization saved to ../outputs\image_485_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_490.jpg...
#   Visualization saved to ../outputs\image_490_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_492.jpg...
#   Visualization saved to ../outputs\image_492_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_493.jpg...
#   Visualization saved to ../outputs\image_493_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.
# Processing image_494.jpg...
#   Visualization saved to ../outputs\image_494_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_497.jpg...
#   Visualization saved to ../outputs\image_497_occluded.png
# 	  Occluded: 7 SAM masks inside annotations.
# Processing image_51.jpg...
#   Visualization saved to ../outputs\image_51_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_56.jpg...
#   Visualization saved to ../outputs\image_56_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_57.jpg...
#   Visualization saved to ../outputs\image_57_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_60.jpg...
#   Visualization saved to ../outputs\image_60_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_61.jpg...
#   Visualization saved to ../outputs\image_61_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_62.jpg...
#   Visualization saved to ../outputs\image_62_occluded.png
# 	  Occluded: 5 SAM masks inside annotations.
# Processing image_66.jpg...
#   Visualization saved to ../outputs\image_66_occluded.png
# 	  Occluded: 1 SAM masks inside annotations.
# Processing image_71.jpg...
#   Visualization saved to ../outputs\image_71_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_77.jpg...
#   Visualization saved to ../outputs\image_77_occluded.png
# 	  Occluded: 4 SAM masks inside annotations.
# Processing image_78.jpg...
#   Visualization saved to ../outputs\image_78_occluded.png
# 	  Occluded: 34 SAM masks inside annotations.
# Processing image_80.jpg...
#   Visualization saved to ../outputs\image_80_occluded.png
# 	  Occluded: 1 SAM masks inside annotations.
# Processing image_81.jpg...
#   Visualization saved to ../outputs\image_81_occluded.png
# 	  Occluded: 0 SAM masks inside annotations.
# Processing image_82.jpg...
#   Visualization saved to ../outputs\image_82_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_85.jpg...
#   Visualization saved to ../outputs\image_85_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_88.jpg...
#   Visualization saved to ../outputs\image_88_occluded.png
# 	  Occluded: 3 SAM masks inside annotations.
# Processing image_9.jpg...
#   Visualization saved to ../outputs\image_9_occluded.png
# 	  Occluded: 6 SAM masks inside annotations.
# Processing image_90.jpg...
#   Visualization saved to ../outputs\image_90_occluded.png
# 	  Occluded: 13 SAM masks inside annotations.
# Processing image_92.jpg...
#   Visualization saved to ../outputs\image_92_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_96.jpg...
#   Visualization saved to ../outputs\image_96_occluded.png
# 	  Occluded: 8 SAM masks inside annotations.
# Processing image_99.jpg...
#   Visualization saved to ../outputs\image_99_occluded.png
# 	  Occluded: 9 SAM masks inside annotations.

# %% [markdown]
# ## Run the model on the not occluded images

# %%
##################################################################
#                                                                #
#   Filter all the images in the not occluded dir and run model  #
#                                                                #
##################################################################

VIS_IMAGES = [f for f in os.listdir(VISIBLE_DIR) if f.endswith((".jpg", ".jpeg", ".png"))]

for file in sorted(VIS_IMAGES):
    json_file = os.path.join(LABEL_DIR, os.path.splitext(file)[0] + ".json")
    
    if not os.path.exists(json_file):
        # Not all scraped images were considered suitable for defining ground truth. 
        # Warn that this file has no .json and is not included in futher processing
        print(f"\t  WARNING: No annotation found for {file} in directory, skipping.")
        continue

    print(f"Processing {file}...")

    img_vis = Image.open(os.path.join(VISIBLE_DIR, file)).convert("RGB")
    vis_array = np.array(img_vis)
    img_h, img_w = vis_array.shape[:2]

    gt_vis = load_gt_masks(json_file, img_h, img_w)

    # Use model on array
    sam_vis = mask_generator.generate(vis_array)
    filtered_vis = filter_masks_by_annotation(sam_vis, gt_vis)
    all_results["not_occluded"][file] = [
        {"label": m["label"], "annot_iou": m["annot_iou"]} for m in filtered_vis
    ]
    save_masked_visualization(vis_array, filtered_vis, gt_vis, file, "not occluded", OUT_DIR)
    print(f"\t  Not occluded: {len(filtered_vis)} SAM masks inside annotations.")


    # Free memory
    del sam_vis
    del filtered_vis
    del vis_array
    gc.collect()

    if torch.cuda.is_available():
        torch.cuda.empty_cache()
# Out:
# Processing image_103.jpg...
#   Visualization saved to ../outputs\image_103_not occluded.png
# 	  Not occluded: 14 SAM masks inside annotations.
# Processing image_109.jpg...
#   Visualization saved to ../outputs\image_109_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_110.jpg...
#   Visualization saved to ../outputs\image_110_not occluded.png
# 	  Not occluded: 14 SAM masks inside annotations.
# Processing image_111.jpg...
#   Visualization saved to ../outputs\image_111_not occluded.png
# 	  Not occluded: 10 SAM masks inside annotations.
# Processing image_112.jpg...
#   Visualization saved to ../outputs\image_112_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_113.jpg...
#   Visualization saved to ../outputs\image_113_not occluded.png
# 	  Not occluded: 8 SAM masks inside annotations.
# Processing image_114.jpg...
#   Visualization saved to ../outputs\image_114_not occluded.png
# 	  Not occluded: 10 SAM masks inside annotations.
# Processing image_126.jpg...
#   Visualization saved to ../outputs\image_126_not occluded.png
# 	  Not occluded: 18 SAM masks inside annotations.
# Processing image_13.jpg...
#   Visualization saved to ../outputs\image_13_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_146.jpg...
#   Visualization saved to ../outputs\image_146_not occluded.png
# 	  Not occluded: 11 SAM masks inside annotations.
# Processing image_148.jpg...
#   Visualization saved to ../outputs\image_148_not occluded.png
# 	  Not occluded: 11 SAM masks inside annotations.
# Processing image_15.jpg...
#   Visualization saved to ../outputs\image_15_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_151.jpg...
#   Visualization saved to ../outputs\image_151_not occluded.png
# 	  Not occluded: 2 SAM masks inside annotations.
# Processing image_156.jpg...
#   Visualization saved to ../outputs\image_156_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_160.jpg...
#   Visualization saved to ../outputs\image_160_not occluded.png
# 	  Not occluded: 13 SAM masks inside annotations.
# Processing image_162.jpg...
#   Visualization saved to ../outputs\image_162_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_171.jpg...
#   Visualization saved to ../outputs\image_171_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_176.jpg...
#   Visualization saved to ../outputs\image_176_not occluded.png
# 	  Not occluded: 12 SAM masks inside annotations.
# Processing image_177.jpg...
#   Visualization saved to ../outputs\image_177_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_18.jpg...
#   Visualization saved to ../outputs\image_18_not occluded.png
# 	  Not occluded: 8 SAM masks inside annotations.
# Processing image_185.jpg...
#   Visualization saved to ../outputs\image_185_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_19.jpg...
#   Visualization saved to ../outputs\image_19_not occluded.png
# 	  Not occluded: 2 SAM masks inside annotations.
# Processing image_193.jpg...
#   Visualization saved to ../outputs\image_193_not occluded.png
# 	  Not occluded: 13 SAM masks inside annotations.
# Processing image_207.jpg...
#   Visualization saved to ../outputs\image_207_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_208.jpg...
#   Visualization saved to ../outputs\image_208_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_209.jpg...
#   Visualization saved to ../outputs\image_209_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_210.jpg...
#   Visualization saved to ../outputs\image_210_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_223.jpg...
#   Visualization saved to ../outputs\image_223_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_224.jpg...
#   Visualization saved to ../outputs\image_224_not occluded.png
# 	  Not occluded: 0 SAM masks inside annotations.
# Processing image_227.jpg...
#   Visualization saved to ../outputs\image_227_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_23.jpg...
#   Visualization saved to ../outputs\image_23_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_239.jpg...
#   Visualization saved to ../outputs\image_239_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_24.jpg...
#   Visualization saved to ../outputs\image_24_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_243.jpg...
#   Visualization saved to ../outputs\image_243_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_25.jpg...
#   Visualization saved to ../outputs\image_25_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_251.jpg...
#   Visualization saved to ../outputs\image_251_not occluded.png
# 	  Not occluded: 14 SAM masks inside annotations.
# Processing image_254.jpg...
#   Visualization saved to ../outputs\image_254_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_266.jpg...
#   Visualization saved to ../outputs\image_266_not occluded.png
# 	  Not occluded: 11 SAM masks inside annotations.
# Processing image_267.jpg...
#   Visualization saved to ../outputs\image_267_not occluded.png
# 	  Not occluded: 18 SAM masks inside annotations.
# Processing image_268.jpg...
#   Visualization saved to ../outputs\image_268_not occluded.png
# 	  Not occluded: 11 SAM masks inside annotations.
# Processing image_275.jpg...
#   Visualization saved to ../outputs\image_275_not occluded.png
# 	  Not occluded: 17 SAM masks inside annotations.
# Processing image_278.jpg...
#   Visualization saved to ../outputs\image_278_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_279.jpg...
#   Visualization saved to ../outputs\image_279_not occluded.png
# 	  Not occluded: 15 SAM masks inside annotations.
# Processing image_280.jpg...
#   Visualization saved to ../outputs\image_280_not occluded.png
# 	  Not occluded: 10 SAM masks inside annotations.
# Processing image_281.jpg...
#   Visualization saved to ../outputs\image_281_not occluded.png
# 	  Not occluded: 15 SAM masks inside annotations.
# Processing image_282.jpg...
#   Visualization saved to ../outputs\image_282_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_283.jpg...
#   Visualization saved to ../outputs\image_283_not occluded.png
# 	  Not occluded: 8 SAM masks inside annotations.
# Processing image_284.jpg...
#   Visualization saved to ../outputs\image_284_not occluded.png
# 	  Not occluded: 10 SAM masks inside annotations.
# Processing image_285.jpg...
#   Visualization saved to ../outputs\image_285_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_286.jpg...
#   Visualization saved to ../outputs\image_286_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_287.jpg...
#   Visualization saved to ../outputs\image_287_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_289.jpg...
#   Visualization saved to ../outputs\image_289_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_292.jpg...
#   Visualization saved to ../outputs\image_292_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_293.jpg...
#   Visualization saved to ../outputs\image_293_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_294.jpg...
#   Visualization saved to ../outputs\image_294_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_295.jpg...
#   Visualization saved to ../outputs\image_295_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_297.jpg...
#   Visualization saved to ../outputs\image_297_not occluded.png
# 	  Not occluded: 12 SAM masks inside annotations.
# Processing image_299.jpg...
#   Visualization saved to ../outputs\image_299_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_306.jpg...
#   Visualization saved to ../outputs\image_306_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_31.jpg...
#   Visualization saved to ../outputs\image_31_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_311.jpg...
#   Visualization saved to ../outputs\image_311_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_318.jpg...
#   Visualization saved to ../outputs\image_318_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_319.jpg...
#   Visualization saved to ../outputs\image_319_not occluded.png
# 	  Not occluded: 1 SAM masks inside annotations.
# Processing image_322.jpg...
#   Visualization saved to ../outputs\image_322_not occluded.png
# 	  Not occluded: 11 SAM masks inside annotations.
# Processing image_327.jpg...
#   Visualization saved to ../outputs\image_327_not occluded.png
# 	  Not occluded: 2 SAM masks inside annotations.
# Processing image_329.jpg...
#   Visualization saved to ../outputs\image_329_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_33.jpg...
#   Visualization saved to ../outputs\image_33_not occluded.png
# 	  Not occluded: 8 SAM masks inside annotations.
# Processing image_332.jpg...
#   Visualization saved to ../outputs\image_332_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_334.jpg...
#   Visualization saved to ../outputs\image_334_not occluded.png
# 	  Not occluded: 12 SAM masks inside annotations.
# Processing image_335.jpg...
#   Visualization saved to ../outputs\image_335_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_337.jpg...
#   Visualization saved to ../outputs\image_337_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_346.jpg...
#   Visualization saved to ../outputs\image_346_not occluded.png
# 	  Not occluded: 15 SAM masks inside annotations.
# Processing image_349.jpg...
#   Visualization saved to ../outputs\image_349_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_352.jpg...
#   Visualization saved to ../outputs\image_352_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_356.jpg...
#   Visualization saved to ../outputs\image_356_not occluded.png
# 	  Not occluded: 9 SAM masks inside annotations.
# Processing image_37.jpg...
#   Visualization saved to ../outputs\image_37_not occluded.png
# 	  Not occluded: 2 SAM masks inside annotations.
# Processing image_372.jpg...
#   Visualization saved to ../outputs\image_372_not occluded.png
# 	  Not occluded: 10 SAM masks inside annotations.
# Processing image_374.jpg...
#   Visualization saved to ../outputs\image_374_not occluded.png
# 	  Not occluded: 12 SAM masks inside annotations.
# Processing image_376.jpg...
#   Visualization saved to ../outputs\image_376_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_38.jpg...
#   Visualization saved to ../outputs\image_38_not occluded.png
# 	  Not occluded: 14 SAM masks inside annotations.
# Processing image_385.jpg...
#   Visualization saved to ../outputs\image_385_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_393.jpg...
#   Visualization saved to ../outputs\image_393_not occluded.png
# 	  Not occluded: 10 SAM masks inside annotations.
# Processing image_395.jpg...
#   Visualization saved to ../outputs\image_395_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_4.jpg...
#   Visualization saved to ../outputs\image_4_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_401.jpg...
#   Visualization saved to ../outputs\image_401_not occluded.png
# 	  Not occluded: 11 SAM masks inside annotations.
# Processing image_402.jpg...
#   Visualization saved to ../outputs\image_402_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_404.jpg...
#   Visualization saved to ../outputs\image_404_not occluded.png
# 	  Not occluded: 0 SAM masks inside annotations.
# Processing image_405.jpg...
#   Visualization saved to ../outputs\image_405_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_408.jpg...
#   Visualization saved to ../outputs\image_408_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_41.jpg...
#   Visualization saved to ../outputs\image_41_not occluded.png
# 	  Not occluded: 8 SAM masks inside annotations.
# Processing image_415.jpg...
#   Visualization saved to ../outputs\image_415_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_416.jpg...
#   Visualization saved to ../outputs\image_416_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_417.jpg...
#   Visualization saved to ../outputs\image_417_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_42.jpg...
#   Visualization saved to ../outputs\image_42_not occluded.png
# 	  Not occluded: 10 SAM masks inside annotations.
# Processing image_424.jpg...
#   Visualization saved to ../outputs\image_424_not occluded.png
# 	  Not occluded: 9 SAM masks inside annotations.
# Processing image_427.jpg...
#   Visualization saved to ../outputs\image_427_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_428.jpg...
#   Visualization saved to ../outputs\image_428_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_43.jpg...
#   Visualization saved to ../outputs\image_43_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_432.jpg...
#   Visualization saved to ../outputs\image_432_not occluded.png
# 	  Not occluded: 0 SAM masks inside annotations.
# Processing image_437.jpg...
#   Visualization saved to ../outputs\image_437_not occluded.png
# 	  Not occluded: 1 SAM masks inside annotations.
# Processing image_443.jpg...
#   Visualization saved to ../outputs\image_443_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_446.jpg...
#   Visualization saved to ../outputs\image_446_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_447.jpg...
#   Visualization saved to ../outputs\image_447_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_455.jpg...
#   Visualization saved to ../outputs\image_455_not occluded.png
# 	  Not occluded: 17 SAM masks inside annotations.
# Processing image_46.jpg...
#   Visualization saved to ../outputs\image_46_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_465.jpg...
#   Visualization saved to ../outputs\image_465_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_467.jpg...
#   Visualization saved to ../outputs\image_467_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_469.jpg...
#   Visualization saved to ../outputs\image_469_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_470.jpg...
#   Visualization saved to ../outputs\image_470_not occluded.png
# 	  Not occluded: 12 SAM masks inside annotations.
# Processing image_473.jpg...
#   Visualization saved to ../outputs\image_473_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_477.jpg...
#   Visualization saved to ../outputs\image_477_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_478.jpg...
#   Visualization saved to ../outputs\image_478_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_48.jpg...
#   Visualization saved to ../outputs\image_48_not occluded.png
# 	  Not occluded: 11 SAM masks inside annotations.
# Processing image_481.jpg...
#   Visualization saved to ../outputs\image_481_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_484.jpg...
#   Visualization saved to ../outputs\image_484_not occluded.png
# 	  Not occluded: 10 SAM masks inside annotations.
# Processing image_486.jpg...
#   Visualization saved to ../outputs\image_486_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_487.jpg...
#   Visualization saved to ../outputs\image_487_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_488.jpg...
#   Visualization saved to ../outputs\image_488_not occluded.png
# 	  Not occluded: 0 SAM masks inside annotations.
# Processing image_489.jpg...
#   Visualization saved to ../outputs\image_489_not occluded.png
# 	  Not occluded: 3 SAM masks inside annotations.
# Processing image_49.jpg...
#   Visualization saved to ../outputs\image_49_not occluded.png
# 	  Not occluded: 6 SAM masks inside annotations.
# Processing image_495.jpg...
#   Visualization saved to ../outputs\image_495_not occluded.png
# 	  Not occluded: 8 SAM masks inside annotations.
# Processing image_496.jpg...
#   Visualization saved to ../outputs\image_496_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_52.jpg...
#   Visualization saved to ../outputs\image_52_not occluded.png
# 	  Not occluded: 7 SAM masks inside annotations.
# Processing image_54.jpg...
#   Visualization saved to ../outputs\image_54_not occluded.png
# 	  Not occluded: 10 SAM masks inside annotations.
# Processing image_59.jpg...
#   Visualization saved to ../outputs\image_59_not occluded.png
# 	  Not occluded: 9 SAM masks inside annotations.
# Processing image_69.jpg...
#   Visualization saved to ../outputs\image_69_not occluded.png
# 	  Not occluded: 2 SAM masks inside annotations.
# Processing image_7.jpg...
#   Visualization saved to ../outputs\image_7_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_72.jpg...
#   Visualization saved to ../outputs\image_72_not occluded.png
# 	  Not occluded: 20 SAM masks inside annotations.
# Processing image_73.jpg...
#   Visualization saved to ../outputs\image_73_not occluded.png
# 	  Not occluded: 2 SAM masks inside annotations.
# Processing image_79.jpg...
#   Visualization saved to ../outputs\image_79_not occluded.png
# 	  Not occluded: 16 SAM masks inside annotations.
# Processing image_8.jpg...
#   Visualization saved to ../outputs\image_8_not occluded.png
# 	  Not occluded: 16 SAM masks inside annotations.
# Processing image_86.jpg...
#   Visualization saved to ../outputs\image_86_not occluded.png
# 	  Not occluded: 8 SAM masks inside annotations.
# Processing image_87.jpg...
#   Visualization saved to ../outputs\image_87_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.
# Processing image_91.jpg...
#   Visualization saved to ../outputs\image_91_not occluded.png
# 	  Not occluded: 9 SAM masks inside annotations.
# Processing image_93.jpg...
#   Visualization saved to ../outputs\image_93_not occluded.png
# 	  Not occluded: 14 SAM masks inside annotations.
# Processing image_95.jpg...
#   Visualization saved to ../outputs\image_95_not occluded.png
# 	  Not occluded: 4 SAM masks inside annotations.
# Processing image_97.jpg...
#   Visualization saved to ../outputs\image_97_not occluded.png
# 	  Not occluded: 5 SAM masks inside annotations.

# %% [markdown]
# ## Compare the ground truth with the model

# %% [markdown]
# ### Evaluation loop

# %%
import os
import csv

csv_path = os.path.join(RESULTS_DIR, "sam2_results.csv")
file_exists = os.path.isfile(csv_path)

with open(csv_path, "a", newline="") as csvfile:  # Append to file from greyscale and resize
    writer = csv.writer(csvfile)

    # print header if file does not yet exist
    if not file_exists:
        writer.writerow(["Condition", "File", "Label", "IoU"])

    for condition, files in all_results.items():
        for file, scores in files.items():
            for score in scores:
                writer.writerow([
                    condition,
                    file,
                    score["label"],
                    round(float(score["annot_iou"]), 4)
                ])

print(f"Evaluation complete! Results saved to {csv_path}")
# Out:
# Evaluation complete! Results saved to ../results/sam2_results.csv

# %% [markdown]
# ## Analysis

# %%
df = pd.read_csv(os.path.join(RESULTS_DIR, "sam2_results.csv"))

df["Label"] = df["Label"].str.lower()
df["Condition"] = df["Condition"].str.lower()

print(df.head())
print(f"\nNumber of rows: {len(df)}")
print(f"Condities: {df['Condition'].unique()}")
print(f"Labels: {df['Label'].unique()}")
# Out:
#   Condition           File        Label     IoU
# 0  original   image_10.jpg         raam  0.4485
# 1  original   image_10.jpg         raam  0.5822
# 2  original   image_10.jpg  zonnepaneel  0.8537
# 3  original   image_10.jpg         raam  0.5233
# 4  original  image_103.jpg         raam  0.7358
#
# Number of rows: 9119
# Condities: ['original' 'resized' 'grayscale' 'occluded' 'not_occluded']
# Labels: ['raam' 'zonnepaneel' 'deur']

# %%
summary = df.groupby(["Condition", "Label"])["IoU"].agg(["mean", "std", "count"]).round(4)

print("Mean IoU per condition for each label:")
print(summary)

summary.to_csv(os.path.join(RESULTS_DIR, "iou_summary.csv"))
# Out:
# Mean IoU per condition for each label:
#                             mean     std  count
# Condition    Label
# grayscale    deur         0.8186  0.3293    444
#              raam         0.8543  0.2871   1734
#              zonnepaneel  0.7304  0.3993    102
# not_occluded deur         0.6637  0.1684    192
#              raam         0.5772  0.1768    738
#              zonnepaneel  0.6882  0.1636     36
# occluded     deur         0.5664  0.1752    252
#              raam         0.5313  0.1648    994
#              zonnepaneel  0.7023  0.1856     67
# original     deur         0.6086  0.1788    444
#              raam         0.5515  0.1719   1734
#              zonnepaneel  0.7031  0.1736    102
# resized      deur         0.7266  0.3556    444
#              raam         0.6512  0.3812   1734
#              zonnepaneel  0.4561  0.4296    102

# %%
pivot = df.groupby(["Condition", "Label"])["IoU"].mean().unstack("Condition").round(4)
pivot = pivot[["original", "occluded", "not_occluded"]]

print("Table for paper (mean IoU):")
print(pivot)
# Out:
# Table for paper (mean IoU):
# Condition    original  occluded  not_occluded
# Label
# deur           0.6086    0.5664        0.6637
# raam           0.5515    0.5313        0.5772
# zonnepaneel    0.7031    0.7023        0.6882

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(10, 6))
pivot.plot(kind="bar", ax=ax, colormap="Pastel1", width=0.7)
ax.set_title("Gemiddelde IoU per conditie en label", fontsize=14)
ax.set_xlabel("Label")
ax.set_ylabel("Gemiddelde IoU")
ax.set_ylim(0, 1)
ax.legend(title="Conditie")
ax.tick_params(axis="x", rotation=0)
for p in ax.patches:
    height = p.get_height()
    if not np.isnan(height) and height > 0:
        ax.text(p.get_x() + p.get_width() / 2, height + 0.01, f"{height:.3f}", ha="center", va="bottom", fontsize=8)
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "iou_per_label_occlusion.png"), dpi=150)
plt.show()

# %% [markdown]
# # Run statistical test for non paired data

# %%
import numpy as np
import pandas as pd
from scipy.stats import mannwhitneyu

# Select data
occluded_raw = df[df["Condition"] == "occluded"]["IoU"]
not_occluded_raw = df[df["Condition"] == "not_occluded"]["IoU"]

# Mann-Whitney
U, p = mannwhitneyu(occluded, not_occluded, alternative='two-sided')

# Rank-biserial correlation
n1 = len(occluded)
n2 = len(not_occluded)
r_rb = 1 - (2 * U) / (n1 * n2)

print(f"U-statistic: {U:.4f}")
print(f"p-waarde:    {p:.6f}")
print(f"Rank-biserial correlation: {r_rb:.4f}")
# Out:
# U-statistic: 527425.5000
# p-waarde:    0.000000
# Rank-biserial correlation: 0.1683
